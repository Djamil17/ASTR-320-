# %%
import matplotlib.pyplot as plt

# %%
x=[i/100 for i in range(1,101)]

# %%
U=lambda r: -1/r 
E=lambda r: U(r)+K(r)
us=[U(r) for r in x]
ks=[-1/2*U(r) for r in x]
es=[k+u for (k,u) in zip(us,ks)]

# %%
plt.plot(x,us,label='Potential Energy U(r)')
plt.plot(x,ks,label='Kinetic Energy K(r)')
plt.plot(x,es, label='Total Energy')
plt.legend()
# plt.xticks([], [])
plt.xlabel('r')
# plt.yticks([], [])
plt.ylabel('Energy')
# Out:
# Text(0, 0.5, 'Energy')
